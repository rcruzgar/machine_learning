# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv("./data/dataset_Facebook.csv", delimiter=';')
df.head(4)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
#
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777

# %%
print(df.shape)
print(df.columns.values)
# Out:
# (500, 19)
# ['Page total likes' 'Type' 'Category' 'Post Month' 'Post Weekday'
#  'Post Hour' 'Paid' 'Lifetime Post Total Reach'
#  'Lifetime Post Total Impressions' 'Lifetime Engaged Users'
#  'Lifetime Post Consumers' 'Lifetime Post Consumptions'
#  'Lifetime Post Impressions by people who have liked your Page'
#  'Lifetime Post reach by people who like your Page'
#  'Lifetime People who have liked your Page and engaged with your post'
#  'comment' 'like' 'share' 'Total Interactions']

# %% [markdown]
# #### Check the presence of missing values in the matrix

# %%
msno.matrix(df)

# %% [markdown]
# #### We will substitute the missing values of like and share columns by the mean values

# %%
# train_df['Age'].fillna(value=np.nanmean(train_df['Age'].values),inplace=True)
print(df['share'].values)
#df['like'].describe()
# Out:
# [ 17.  29.  14. 147.  49.  33.  27.  14.  31.  26.  19.  18.  14.  10.
#   20.  18.  12.  20.  17.   8.  12.   0.   2.  24.  19.  18.  72.  17.
#   63.  13.  22.  11.  47.  23.  17.  21.  17.   8.  31.  14.  39.  18.
#    3.  10.  11.  10.  36.   8.  15.   1.   9.  28.  31.  19.  13.  14.
#   54.  13.  11.  17.  14.  10.  13.  22.   7.  23.   7.  70.  17.  28.
#    9.  84.  44.  47.  13.  74.   0.   8.   8.   7.  13.  53.  57.  19.
#   16.   8.  31.  38.   6.  17.  77.  13.  32.  16.  22.  27.  11.  26.
#   61.  90.   0.  95.  14.   4.   9. 139.  32.  28.  16.  50.   4.  nan
#   18.  16.   2.   2.  26.   0.   2.   2.  nan  40.   2.   2.  nan   2.
#   41.   1.   1.   0.   2.   3.   2.   1.   4.  12.  16.   3.  25.  19.
#   44.  36.  90.  60.   9.  14.  15.  14.  28.  11.  41.  32.  49.  25.
#   55.  16.  30.  21.  35.  13.  40.  32.  98.  41.  nan  19.   5.  64.
#  208.  16.  26.   6.  27.  40.  34.  22.  98.  40.  42.  36.  29.   8.
#   44. 121.  11.  10.  35.   6.  12.  15.  15.  43.   7.  17.  42.  43.
#    7.   7.   2. 102.  25.   5.  15.  19.  16.   3.  68.  20.  11.  22.
#    3.  21.  11.   3.  31.  10.   9.   1.  10.  28.   8.  27.  11.  54.
#   21.  17.  26.  11.  25.  19.  20.  20.   1.  10.  21.   1.  45.  23.
#   25.  31.  83.  22.  79.  76. 790.  30.  15.  19.  19.  14.  10.  34.
#   42.  51.  58.   8.  32.  10.  26.  41.  15.  43.  16.   9.  60.  10.
#   24.  13.   7.   4.  28.  47.  31.  27.   7.  14.   5.  44.   5.  39.
#    8.  17.  13.   4.  12.  18.   3.   9.  33.   5.   2.  26.   5.  23.
#   21.   7.  19.  10.  16.   1.  43.  16.  28.  29.   7.  28.  28.  26.
#   18.  20.   3.  13.  12.  14.   4.  23.  17.  14.  44.  49.   5.   6.
#   14.  47.   6.  10.  17.  22.  58.  34.  32.  26.  10.  20.  10.  37.
#    9.  16.  44.  58.  36.  17.  33.  29.  14.  20.  90.  13.  23. 122.
#   32.  33.  39.  25.  18.  38.  16.  40.  29.  54.  24.  18.  36.  30.
#   33.  32.  47.  39.   9.  35.  76. 123.  11.  26.  16.  30.  13.  51.
#   11. 128.  18.  34.  22.  28.  13.  38.   8.  14.   5.   3.  14. 109.
#   18.  13.  21.   6.  27.  11.  18.  52.  26.  38.  17.  40.  24.  26.
#   25.   9.   7.  26.  24.  15.  14.  16.  29.  15.   6.   0.  11.  14.
#   13.   7.   0.   3.   6.  15.   1.  13.   0.   0.   0.   0.   1.  14.
#    1.   4.   0.  13.  15.   9.   7.   0.  97.  10.  20.   7.  21.  24.
#    6.  26.  21.  29.  15.  27.  70.  53.   6.  18.  32.  32. 181.  11.
#   78.  34.  36.  38.  21.  37.  36.  61.  13.  57.  15.  42.  13.  19.
#   47.   5.  31.  36.  99.   2.  36.  26.  24.   2.  25.  21.  80.  28.
#   30.  46.   9.  55.  41.  26.  22.  18.  38.  28.]

# %%
# df['share'].fillna(value=df.share.mode(),inplace=True)
# train_df['Age'].fillna(value=np.nanmean(train_df['Age'].values),inplace=True)
# print(mode(df['share']))

#mode = df['share'].mode()
#print(mode)
# Out:
# 0    13.0
# 1    14.0
# dtype: float64

# %%
df['share'].describe()
# Out:
# count    496.000000
# mean      27.266129
# std       42.613292
# min        0.000000
# 25%       10.000000
# 50%       19.000000
# 75%       32.250000
# max      790.000000
# Name: share, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),cmap='inferno',annot=True,cbar=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-690f1ee2fab2> in <module>
#       1 plt.figure(figsize=(12,10))
# ----> 2 plt.heatmap(df.corr(),cmap='inferno',annot=True,cbar=True)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'heatmap'
